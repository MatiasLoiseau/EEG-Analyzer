# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# file_names = [
#     "golpes2.dat",
#     "cerrados.dat",
#     "mentalimagery.dat",
#     "golpes1.dat",
#     "exhalar.dat",
#     "baseline.dat",
#     "pestaneos.dat",
#     "inhalar.dat"
# ]

# %%
column_names = ['timestamp', 'counter', 'eeg', 'attention', 'meditation', 'blinking']

# %%
golpes2 = pd.read_csv('data/golpes2.dat', delimiter=' ', names = ['timestamp','counter','eeg','attention','meditation','blinking'])

print('Estructura de la informacion:')
print(golpes2.describe())
# Out:
# Estructura de la informacion:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.083000e+04  30830.000000  30830.000000  30830.000000  30830.000000
# mean   1.720128e+09     49.529192     30.118456     26.274635     78.450114
# std    1.731132e+01     28.862371     31.264222     11.540897     22.357515
# min    1.720128e+09      0.000000   -172.000000      0.000000      0.000000
# 25%    1.720128e+09     25.000000     10.000000     16.000000     69.000000
# 50%    1.720128e+09     50.000000     29.000000     26.000000     83.000000
# 75%    1.720128e+09     75.000000     50.000000     34.000000     94.000000
# max    1.720128e+09     99.000000    237.000000     48.000000    100.000000
#
#        blinking
# count   30830.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_golpes2 = golpes2.values
eeg = data_golpes2[:,2]

plt.plot(eeg,'r', label='EEG')
plt.xlabel('t');
plt.ylabel('eeg(t)');
plt.title(r'EEG Signal')
plt.ylim([-400, 400]);
plt.xlim([0,len(eeg)])
plt.show()

# %%
plt.plot(eeg,'r', label='EEG')
plt.xlabel('t');
plt.ylabel('eeg(t)');
plt.title(r'EEG Signal')
plt.ylim([-400, 400]);
plt.xlim([0,len(eeg)/20])
plt.show()

# %%
# Parameters
N = len(eeg)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
cerrados = pd.read_csv('data/cerrados.dat', delimiter=' ', names=column_names)
print('Estructura de la información de cerrados.dat:')
print(cerrados.describe())
# Out:
# Estructura de la información de cerrados.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.085000e+04  30850.000000  30850.000000  30850.000000  30850.000000
# mean   1.720129e+09     49.509076     30.218023     51.647909     63.593679
# std    1.732276e+01     28.868743     38.633094     22.206037     20.306644
# min    1.720129e+09      0.000000   -164.000000      0.000000      0.000000
# 25%    1.720129e+09     25.000000      5.000000     37.000000     56.000000
# 50%    1.720129e+09     50.000000     29.000000     53.000000     67.000000
# 75%    1.720129e+09     75.000000     55.000000     67.000000     75.000000
# max    1.720129e+09     99.000000    208.000000    100.000000     97.000000
#
#        blinking
# count   30850.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_cerrados = cerrados.values
eeg_cerrados = data_cerrados[:, 2]
plt.plot(eeg_cerrados, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - cerrados.dat')
plt.ylim([-400, 400])
plt.xlim([0, len(eeg_cerrados)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_cerrados)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_cerrados)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
mentalimagery = pd.read_csv('data/mentalimagery.dat', delimiter=' ', names=column_names)
print('Estructura de la información de mentalimagery.dat:')
print(mentalimagery.describe())
# Out:
# Estructura de la información de mentalimagery.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.086000e+04  30860.000000  30860.000000  30860.000000  30860.000000
# mean   1.720128e+09     49.497408     29.968600     43.851523     63.836423
# std    1.732306e+01     28.871387     31.156054     21.779379     24.091042
# min    1.720128e+09      0.000000   -154.000000      0.000000      0.000000
# 25%    1.720128e+09     24.000000      9.000000     29.000000     54.000000
# 50%    1.720128e+09     49.500000     29.000000     47.000000     69.000000
# 75%    1.720128e+09     75.000000     50.000000     61.000000     78.000000
# max    1.720128e+09     99.000000    251.000000     96.000000    100.000000
#
#        blinking
# count   30860.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_mentalimagery = mentalimagery.values
eeg_mentalimagery = data_mentalimagery[:, 2]
plt.plot(eeg_mentalimagery, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - mentalimagery.dat')
plt.ylim([-400, 400])
plt.xlim([0, len(eeg_mentalimagery)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_mentalimagery)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_mentalimagery)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
golpes1 = pd.read_csv('data/golpes1.dat', delimiter=' ', names=column_names)
print('Estructura de la información de golpes1.dat:')
print(golpes1.describe())
# Out:
# Estructura de la información de golpes1.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.084000e+04  30840.000000  30840.000000  30840.000000  30840.000000
# mean   1.720128e+09     49.517510     29.878210     43.055642     48.892802
# std    1.731721e+01     28.869577     63.208986     25.613358     23.776196
# min    1.720128e+09      0.000000   -482.000000      0.000000      0.000000
# 25%    1.720128e+09     25.000000      6.000000     24.000000     34.000000
# 50%    1.720128e+09     50.000000     29.000000     43.000000     50.000000
# 75%    1.720128e+09     75.000000     53.000000     57.000000     67.000000
# max    1.720128e+09     99.000000    584.000000    100.000000     90.000000
#
#        blinking
# count   30840.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_golpes1 = golpes1.values
eeg_golpes1 = data_golpes1[:, 2]
plt.plot(eeg_golpes1, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - golpes1.dat')
plt.ylim([-600, 600])
plt.xlim([0, len(eeg_golpes1)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_golpes1)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_golpes1)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
exhalar = pd.read_csv('data/exhalar.dat', delimiter=' ', names=column_names)
print('Estructura de la información de exhalar.dat:')
print(exhalar.describe())
# Out:
# Estructura de la información de exhalar.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.084000e+04  30840.000000  30840.000000  30840.000000  30840.000000
# mean   1.720128e+09     49.503243     30.816375     62.267866     70.086025
# std    1.731708e+01     28.872727     50.762146     20.581632     28.134058
# min    1.720128e+09      0.000000   -317.000000      0.000000      0.000000
# 25%    1.720128e+09     24.000000      5.000000     53.000000     66.000000
# 50%    1.720128e+09     50.000000     29.000000     63.000000     80.000000
# 75%    1.720128e+09     75.000000     56.000000     75.000000     90.000000
# max    1.720128e+09     99.000000    566.000000    100.000000    100.000000
#
#        blinking
# count   30840.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_exhalar = exhalar.values
eeg_exhalar = data_exhalar[:, 2]
plt.plot(eeg_exhalar, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - exhalar.dat')
plt.ylim([-600, 600])
plt.xlim([0, len(eeg_exhalar)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_exhalar)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_exhalar)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
baseline = pd.read_csv('data/baseline.dat', delimiter=' ', names=column_names)
print('Estructura de la información de baseline.dat:')
print(baseline.describe())
# Out:
# Estructura de la información de baseline.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.085000e+04  30850.000000  30850.000000  30850.000000  30850.000000
# mean   1.720127e+09     49.492545     31.187650     59.567715     31.553452
# std    1.732344e+01     28.864605     45.542218     20.964926     17.639384
# min    1.720127e+09      0.000000   -433.000000      0.000000      0.000000
# 25%    1.720127e+09     25.000000      8.000000     51.000000     16.000000
# 50%    1.720127e+09     49.000000     32.000000     63.000000     34.000000
# 75%    1.720127e+09     74.000000     54.000000     70.000000     47.000000
# max    1.720127e+09     99.000000    560.000000    100.000000     69.000000
#
#        blinking
# count   30850.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_baseline = baseline.values
eeg_baseline = data_baseline[:, 2]
plt.plot(eeg_baseline, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - baseline.dat')
plt.ylim([-400, 400])
plt.xlim([0, len(eeg_baseline)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_baseline)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_baseline)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
pestaneos = pd.read_csv('data/pestaneos.dat', delimiter=' ', names=column_names)
print('Estructura de la información de pestaneos.dat:')
print(pestaneos.describe())
# Out:
# Estructura de la información de pestaneos.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.082600e+04  30826.000000  30826.000000  30826.000000  30826.000000
# mean   1.720128e+09     49.509473     31.113962     26.783754     53.908876
# std    1.730934e+01     28.876583    300.791598     17.653374     25.095712
# min    1.720128e+09      0.000000   -709.000000      0.000000      0.000000
# 25%    1.720128e+09     24.000000   -130.000000     16.000000     35.000000
# 50%    1.720128e+09     50.000000     39.000000     26.000000     54.000000
# 75%    1.720128e+09     75.000000    144.000000     41.000000     78.000000
# max    1.720128e+09     99.000000   1056.000000     61.000000    100.000000
#
#        blinking
# count   30826.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_pestaneos = pestaneos.values
eeg_pestaneos = data_pestaneos[:, 2]
plt.plot(eeg_pestaneos, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - pestaneos.dat')
plt.ylim([-1000, 1000])
plt.xlim([0, len(eeg_pestaneos)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_pestaneos)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_pestaneos)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()

# %%
inhalar = pd.read_csv('data/inhalar.dat', delimiter=' ', names=column_names)
print('Estructura de la información de inhalar.dat:')
print(inhalar.describe())
# Out:
# Estructura de la información de inhalar.dat:
#           timestamp       counter           eeg     attention    meditation  \
# count  3.084000e+04  30840.000000  30840.000000  30840.000000  30840.000000
# mean   1.720128e+09     49.496757     30.657328      8.534501     67.887354
# std    1.731727e+01     28.876320     47.265452     11.327053     21.584064
# min    1.720128e+09      0.000000   -342.000000      0.000000      0.000000
# 25%    1.720128e+09     24.000000      5.000000      1.000000     60.000000
# 50%    1.720128e+09     50.000000     29.000000      3.000000     67.000000
# 75%    1.720128e+09     75.000000     55.000000     10.000000     83.000000
# max    1.720128e+09     99.000000    397.000000     47.000000    100.000000
#
#        blinking
# count   30840.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
data_inhalar = inhalar.values
eeg_inhalar = data_inhalar[:, 2]
plt.plot(eeg_inhalar, 'r', label='EEG')
plt.xlabel('t')
plt.ylabel('eeg(t)')
plt.title('EEG Signal - inhalar.dat')
plt.ylim([-400, 450])
plt.xlim([0, len(eeg_inhalar)])
plt.legend()
plt.show()

# %%
# Parameters
N = len(eeg_inhalar)  # Number of samples
T = 1.0 / 512.0  # Sample spacing

# Fourier transform and frequency domain plot
yf = np.fft.fft(eeg_inhalar)
xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.title(r'Signal spectrum.')
#plt.ylim([-400, 400]);
plt.xlim([0,100])
#plt.axis((0, 60, 0, 9))
plt.show()
